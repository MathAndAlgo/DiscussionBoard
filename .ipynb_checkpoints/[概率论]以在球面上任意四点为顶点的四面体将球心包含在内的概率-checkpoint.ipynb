# %%
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

### 圆/三角形


#### Adapted from  https://github.com/MathAndAlgo/DiscussionBoard/issues/7 @guofei9987
def func1_metric(x,x1,x2,is_theta=1):
    # is_theta=1,说明x输入的是极坐标，
    # is_theta=0,说明x输入的是笛卡尔坐标
    if is_theta==1:
        x=[np.cos(x),np.sin(x)]
    elif is_theta==0:
        x=[0,0]
    x1=[np.cos(x1),np.sin(x1)]
    x2=[np.cos(x2),np.sin(x2)]
    return (x[1]-x1[1])*(x2[0]-x1[0])-(x2[1]-x1[1])*(x[0]-x1[0])

def is_in(tri_a):
#     tri_a = np.array(tri_a)
    for i in range(3):
        tri_a_temp=tri_a[:]
        tri_a_x0=list(tri_a_temp).pop(i)
        if func1_metric(tri_a_x0,tri_a_temp[0],tri_a_temp[1])*func1_metric(0,tri_a_temp[0],tri_a_temp[1],is_theta=0)<0:
            return 0
    return 1

def is_in__angle(tri_a):
    '''
    通过判断是否为三角形得出圆心相对三角形位置（直角三角形圆心在斜边上）
    输入：（3,）阵列或 (n,3)阵列
    '''
    tri_a.sort(axis = -1)
    if tri_a.ndim is 1:
        tri_a = tri_a[None,:]
    tri_a = np.hstack([tri_a, tri_a[:,0:1] + 2*np.pi])
    angs = np.diff(tri_a,axis = -1)
    return angs.max(axis = -1,keepdims = 1) < np.pi

if __name__ =='__main__':
    tri_a = np.random.uniform(low=0,high=2*np.pi,size=(20,3))
    is_in__angle(tri_a)

# %%
tri_a = np.random.uniform(low=0,high=2*np.pi,size=(3,))
# %timeit is_in__angle(tri_a)
# %timeit is_in(tri_a)
# Out:
# The slowest run took 13.47 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 17.1 µs per loop
# 10000 loops, best of 3: 63.1 µs per loop

# %%
tri_a=np.random.uniform(low=0,high=2*np.pi,size=3)
plt.subplot(111,polar=True)
plt.plot(tri_a,[1,1,1],'r')
plt.plot([tri_a[0],tri_a[-1]],[1,1],'r')
plt.show()
# if is_in__angle(tri_a)[0]==0:
# ?np.array
tri_a = pol2cart(tri_a)
tri_a = np.concatenate([tri_a,tri_a[:,0:1]*0],axis = 1)
if is_in__area(tri_a)==0:
    print('不在内部')
else: print('在内部')
# Out:
# 0.272976442638 0.616278375374
# 在内部

# %%
# tri_a
def pol2cart(alpha):
    return np.vstack([np.cos(alpha),np.sin(alpha)]).T
# pol2cart(tri_a).shape
# Out:
# (3, 2)

# %%
total_counts=100000
tri_a=np.random.uniform(low=0,high=2*np.pi,size=(total_counts,3))
res = is_in__angle(tri_a)
prob = res.mean()
print 'simulations: %d, in_prob: %f'%(total_counts,prob )
# Out:
# simulations: 100000, in_prob: 0.249440

# %%
### Adapted from http://matplotlib.1069221.n5.nabble.com/matplotlib-3D-interpolated-shading-td7989.html
from mpl_toolkits.mplot3d import Axes3D 
import numpy as np 
from matplotlib import cm 
import matplotlib.pyplot as plt 

import scipy
# points = np.random.rand(4, 3)   # 30 random points in 2-D
def plotTetra(points):
    hull = scipy.spatial.ConvexHull(points)
    x,y,z = points[:,0], points[:,1], points[:,2] 
    fig = plt.figure(figsize=(4.0,4.0)) 
    ax = fig.add_subplot(111, projection = '3d') 
    S = ax.plot_trisurf(x,y,z,triangles = hull.simplices ,shade = True, cmap=cm.copper,lw=0.15) 
#     v1 = p3 - p1
#     v2 = p2 - p1
    # the cross product is a vector normal to the plane
    crosspd = np.cross(points[1,:] - points[0,:], points[2,:] - points[1,:])
    print crosspd
    st = points[:3,:].mean(axis = 0)
#     print points.shape
    end= st + crosspd
    coord = np.vstack([st,end])
#     print coord.shape
    ax.plot(coord[:,0],coord[:,1],coord[:,2],color = 'b')
#     ax.plot([st[][0,crosspd[0]],[0,crosspd[1]],[0,crosspd[2]],color = 'b')
#     ax.plot([0,crosspd[0]],[0,crosspd[1]],[0,crosspd[2]],color = 'b')
#     ax.scatter(crosspd)
    ax.scatter(x[:3],y[:3],z[:3])
#     ax.scatter(0,0,0,'x')
    ax.scatter(*st,color = 'red')
    return ax
def pdarea(orig,ends):
#     orig = np.array(orig)
    return np.cross(* ends- orig)
# def cycarea(points):
#     points[0,0] * (points[1,1])
def is_in__area(points,orig = [0,0,0]):
    a0 = pdarea(orig,points[ :2,:])
    a1 = pdarea(orig,points[1:3,:])
    a2 = pdarea(orig,np.take(points,[2,0],axis = 0))
    s1 = np.dot(a0,a1)
    s2 = np.dot(a0,a2)
    print s1,s2
    s = np.dot(a0,np.vstack([a1,a2]).T)
#     print s.prod() > 0 
#     return s.prod() > 0
    return s.min() > 0 
points = np.random.uniform(low= -np.pi,high=np.pi,size=(npt,3))
is_in__area(points)                
#     pdarea(points[:3,:])
#     points[0,1]
#     origin 
pdarea([0,0,0],points[:2,:])
    

# np.linalg.det
# points.shape
# points = points[:4,:]
# points.shape
points = np.random.uniform(low= -np.pi,high=np.pi,size=(4,3))

def sp2cart(r,phi = None,theta = None):
    if isinstance(r, np.ndarray):
        if r.shape[-1]==3:
    #         tmp = np.take(r,[0,1,2],axis=-1)
            phi = np.take(r,1,axis = -1)
            theta = np.take(r,2,axis = -1)
            r = np.take(r,0,axis = -1,)
    #         return tmp
    psin = np.sin(phi)
    return  r[:,None] * np.vstack([psin * np.cos(theta),
                                   psin * np.sin(theta), 
                                   np.cos(phi)]).T


def is_in__Det(points,test_pt = [0,0,0]):
    '''
    Adapted from http://steve.hollasch.net/cgindex/geometry/ptintet.html
    '''
    mat0 = np.hstack([points,
              np.ones((points.shape[0],1))])
    D0 = np.linalg.det(mat0)
    test_pt = [0,0,0]
    Ds = []
    for i in range(mat0.shape[0]):
        mat1 = mat0.copy()
        mat1[i,:3] = test_pt
        Ds += [np.linalg.det(mat1)]
        Ss = np.sign(Ds)
    return np.min(Ss ==Ss[0]) == 1
is_in__Det(points)

#     ax.scatter(st[0],st[1],st[2])
# Out:
# 15.7470490508 16.9102909577
# False

# %%
# fig = plt.figure(figsize=(8.0,8.0)) 
# ax = fig.add_subplot(111, projection='3d') 
npt = 1000
points = np.random.uniform(low= -np.pi,high=np.pi,size=(npt,3))
oints = np.random.uniform(low= -np.pi,high=np.pi,size=(npt,3))
points[:,0] = 1
points = sp2cart(points)
Tet = points[:4,:]
ax = plotTetra(Tet)
ax.scatter(*points.T,s = 0.5)
ax.scatter(*[0,0,0])
LIM = [-1.1,1.1]
ax.set_xlim(LIM)
ax.set_ylim(LIM)
ax.set_zlim(LIM)
is_in__Det(Tet)

# points
# Out:
# [ 2.26582098 -0.53033675  0.46438831]
# False

# %%
fig = plt.figure(figsize=(8.0,8.0)) 
ax = fig.add_subplot(111, projection='3d') 

npt = 6000
points = np.random.uniform(low= -np.pi,high=np.pi,size=(npt,3))
# points = np.random.uniform(low= 0,high=np.pi,size=(npt,3))
# theta = np.random.uniform(low= 0,high=2*np.pi,size=(npt,3))
# points = np.random.rand(1000, 3)   # 30 random points in 2-D
points[:,0] = 1
points = sp2cart(points)
# points = sp2cart(1,phi,theta)
x,y,z = points[:,0], points[:,1], points[:,2] 
ax.scatter(x,y,z, s = 0.3)
# ?ax.scatter

# %%
fig = plt.figure(figsize=(8.0,8.0)) 
ax = fig.add_subplot(111, projection='3d') 

npt = 6000
theta = np.random.uniform(low= -np.pi,high=np.pi,size=npt)
phi = np.arccos((np.random.uniform(low = -1.,high = 1.,size=npt))) 
# phi = np.arcsin(np.sqrt(np.random.uniform(low = 0,high = 1.,size=npt))) * 2
r = np.ones(phi.shape)
sp_points = np.vstack([r,phi,theta]).T
# points = np.random.rand(1000, 3)   # 30 random points in 2-D
points = sp2cart(sp_points)
# points = sp2cart(1,phi,theta)
x,y,z = points[:,0], points[:,1], points[:,2] 
ax.scatter(x,y,z, s = 0.3)
# ?ax.scatter

# %%
print "hi"
# Out:
# hi

# %%
npt = 5000000
theta = np.random.uniform(low= -np.pi,high=np.pi,size=npt)
phi = np.arccos((np.random.uniform(low = -1.,high = 1.,size=npt))) 
# phi = np.arcsin(np.sqrt(np.random.uniform(low = 0,high = 1.,size=npt))) * 2
r = np.ones(phi.shape)
sp_points = np.vstack([r,phi,theta]).T
# points = np.random.rand(1000, 3)    # 30 random points in 2-D
points = sp2cart(sp_points)
import multiprocessing as mp
p = mp.Pool(16)
# res = map(is_in__Det,np.split(points,np.arange(4,len(points),4)))
res = p.map(is_in__Det,np.split(points,np.arange(4,len(points),4)))
p.close()
prob = np.mean(res)
print prob
# np.split([1,2,3,4,5,6],[3])
# Out:
# 0.1249552

# %%
# res[-1000:]
# np
# xs = []
ys = []
for I in np.linspace(0,len(res),1000).astype('int'):
    ys += [np.mean(res[:I])]
# Out:
# /home/shouldsee/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/shouldsee/.local/lib/python2.7/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
ys = []
for I in np.linspace(0,len(res),1000).astype('int'):
    ys += [np.mean(res[:I])]
plt.plot(ys)
# Out:
# /home/shouldsee/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/shouldsee/.local/lib/python2.7/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.plot(ys)
